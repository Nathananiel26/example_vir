# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv("Datasets/sales_data.csv")
data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        294049    Lightning Charging Cable                1      14.95
# 1        294050            Wired Headphones                1      11.99
# 2        294051        USB-C Charging Cable                2      11.95
# 3        294052            Wired Headphones                1      11.99
# 4        294053            27in FHD Monitor                1     149.99
# ...         ...                         ...              ...        ...
# 185558   216589  Bose SoundSport Headphones                1      99.99
# 185559   216590            Wired Headphones                1      11.99
# 185560   216591    Lightning Charging Cable                1      14.95
# 185561   216592       AA Batteries (4-pack)                1       3.84
# 185562   216593  Bose SoundSport Headphones                1      99.99
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ## Checking your dataframe

# %%
data.head(15)
# Out:
#    Order ID                   Product Quantity Ordered Price Each  \
# 0    294049  Lightning Charging Cable                1      14.95
# 1    294050          Wired Headphones                1      11.99
# 2    294051      USB-C Charging Cable                2      11.95
# 3    294052          Wired Headphones                1      11.99
# 4    294053          27in FHD Monitor                1     149.99
# 5    294054                    iPhone                1      700.0
# 6    294055      USB-C Charging Cable                1      11.95
# 7    294056  Lightning Charging Cable                1      14.95
# 8    294057              Google Phone                1      600.0
# 9    294058     AA Batteries (4-pack)                1       3.84
# 10   294059      USB-C Charging Cable                1      11.95
# 11   294060      USB-C Charging Cable                1      11.95
# 12   294061           ThinkPad Laptop                1     999.99
# ...

# %%
df = data.copy()

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     185078                185078           185078     185078
# unique    177210                    20               11         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         346                 21867           167426      21867
#
#         Order Date  Purchase Address
# count       185078            185078
# unique      141845            140081
# top     Order Date  Purchase Address
# freq           346               346

# %% [markdown]
# ## Removing Null Values & Converting Datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185563 entries, 0 to 185562
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185078 non-null  object
#  1   Product           185078 non-null  object
#  2   Quantity Ordered  185078 non-null  object
#  3   Price Each        185078 non-null  object
#  4   Order Date        185078 non-null  object
#  5   Purchase Address  185078 non-null  object
# dtypes: object(6)
# memory usage: 8.5+ MB

# %%
df.shape
# Out:
# (185563, 6)

# %%
df.isnull().sum()
# Out:
# Order ID            485
# Product             485
# Quantity Ordered    485
# Price Each          485
# Order Date          485
# Purchase Address    485
# dtype: int64

# %%
df.dropna(how = "all" , inplace = True)

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
for each_col in df.columns:
    print(each_col)
# Out:
# Order ID
# Product
# Quantity Ordered
# Price Each
# Order Date
# Purchase Address

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185078 entries, 0 to 185562
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185078 non-null  object
#  1   Product           185078 non-null  object
#  2   Quantity Ordered  185078 non-null  object
#  3   Price Each        185078 non-null  object
#  4   Order Date        185078 non-null  object
#  5   Purchase Address  185078 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
#df["Quantity Ordered"]= pd.to_numeric(df["Quantity Ordered"]).......this gave us an error ,esage indicating that quantity ordered values inclues a string so we need to remove non numeric values out

# %%
df["Quantity Ordered"].unique()
# Out:
# array(['1', '2', '4', '3', 'Quantity Ordered', '5', '6', '7', '8', '10',
#        '9'], dtype=object)

# %%
#df = df[df["Quantity Ordered"] != "Quantity Ordered"]

# %%
df["Quantity Ordered"].unique()
# Out:
# array(['1', '2', '4', '3', 'Quantity Ordered', '5', '6', '7', '8', '10',
#        '9'], dtype=object)

# %%
df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185078 entries, 0 to 185562
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185078 non-null  object
#  1   Product           185078 non-null  object
#  2   Quantity Ordered  184732 non-null  float64
#  3   Price Each        185078 non-null  object
#  4   Order Date        185078 non-null  object
#  5   Purchase Address  185078 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 9.9+ MB

# %%
df = df[df["Order Date"] != "Order Date"]

# %%
#, format= "%y-%m-%d"
df["Order Date"]  = pd.to_datetime(df["Order Date"])
# Out:
# C:\Users\USERE\AppData\Local\Temp\ipykernel_10756\4189876447.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Order Date"]  = pd.to_datetime(df["Order Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 184732 entries, 0 to 185562
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          184732 non-null  object
#  1   Product           184732 non-null  object
#  2   Quantity Ordered  184732 non-null  float64
#  3   Price Each        184732 non-null  object
#  4   Order Date        184732 non-null  datetime64[ns]
#  5   Purchase Address  184732 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 9.9+ MB

# %%
df["Price Each"] = df["Price Each"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 184732 entries, 0 to 185562
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          184732 non-null  object
#  1   Product           184732 non-null  object
#  2   Quantity Ordered  184732 non-null  float64
#  3   Price Each        184732 non-null  float64
#  4   Order Date        184732 non-null  datetime64[ns]
#  5   Purchase Address  184732 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 9.9+ MB

# %%
df["Price Each"].max()
# Out:
# np.float64(1700.0)

# %%
df["Quantity Ordered"].max()
# Out:
# np.float64(10.0)

# %% [markdown]
# ## Creating New columns from the existing data

# %%
df["Purchase Amount"] = df["Quantity Ordered"] * df["Price Each"]

# %%
df.head(5)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   294049  Lightning Charging Cable               1.0       14.95
# 1   294050          Wired Headphones               1.0       11.99
# 2   294051      USB-C Charging Cable               2.0       11.95
# 3   294052          Wired Headphones               1.0       11.99
# 4   294053          27in FHD Monitor               1.0      149.99
#
#            Order Date                         Purchase Address  \
# 0 2019-12-22 19:16:00      939 Odomankuma St, Kumasi, AS 40001
# 1 2019-12-30 18:15:00  116 Kwaku Boateng St, Sunyani, BA 10001
# 2 2019-12-25 16:17:00             924 1st St, Kumasi, AS 40001
# 3 2019-12-24 13:15:00                148 12th St, Wa, UE 48101
# 4 2019-12-06 21:21:00           172 Nii Armah St, Ho, VR 90001
#
#    Purchase Amount
# 0            14.95
# 1            11.99
# 2            23.90
# 3            11.99
# 4           149.99

# %%
df["Year"] = df["Order Date"].dt.year

# %%
df.head(5)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   294049  Lightning Charging Cable               1.0       14.95
# 1   294050          Wired Headphones               1.0       11.99
# 2   294051      USB-C Charging Cable               2.0       11.95
# 3   294052          Wired Headphones               1.0       11.99
# 4   294053          27in FHD Monitor               1.0      149.99
#
#            Order Date                         Purchase Address  \
# 0 2019-12-22 19:16:00      939 Odomankuma St, Kumasi, AS 40001
# 1 2019-12-30 18:15:00  116 Kwaku Boateng St, Sunyani, BA 10001
# 2 2019-12-25 16:17:00             924 1st St, Kumasi, AS 40001
# 3 2019-12-24 13:15:00                148 12th St, Wa, UE 48101
# 4 2019-12-06 21:21:00           172 Nii Armah St, Ho, VR 90001
#
#    Purchase Amount  Year
# 0            14.95  2019
# 1            11.99  2019
# 2            23.90  2019
# 3            11.99  2019
# 4           149.99  2019

# %%
df["Month"] = df["Order Date"].dt.month_name()

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   294049  Lightning Charging Cable               1.0       14.95
# 1   294050          Wired Headphones               1.0       11.99
# 2   294051      USB-C Charging Cable               2.0       11.95
# 3   294052          Wired Headphones               1.0       11.99
# 4   294053          27in FHD Monitor               1.0      149.99
#
#            Order Date                         Purchase Address  \
# 0 2019-12-22 19:16:00      939 Odomankuma St, Kumasi, AS 40001
# 1 2019-12-30 18:15:00  116 Kwaku Boateng St, Sunyani, BA 10001
# 2 2019-12-25 16:17:00             924 1st St, Kumasi, AS 40001
# 3 2019-12-24 13:15:00                148 12th St, Wa, UE 48101
# 4 2019-12-06 21:21:00           172 Nii Armah St, Ho, VR 90001
#
#    Purchase Amount  Year     Month
# 0            14.95  2019  December
# 1            11.99  2019  December
# 2            23.90  2019  December
# 3            11.99  2019  December
# ...

# %%
df["Day"] = df["Order Date"].dt.day_name()

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   294049  Lightning Charging Cable               1.0       14.95
# 1   294050          Wired Headphones               1.0       11.99
# 2   294051      USB-C Charging Cable               2.0       11.95
# 3   294052          Wired Headphones               1.0       11.99
# 4   294053          27in FHD Monitor               1.0      149.99
#
#            Order Date                         Purchase Address  \
# 0 2019-12-22 19:16:00      939 Odomankuma St, Kumasi, AS 40001
# 1 2019-12-30 18:15:00  116 Kwaku Boateng St, Sunyani, BA 10001
# 2 2019-12-25 16:17:00             924 1st St, Kumasi, AS 40001
# 3 2019-12-24 13:15:00                148 12th St, Wa, UE 48101
# 4 2019-12-06 21:21:00           172 Nii Armah St, Ho, VR 90001
#
#    Purchase Amount  Year     Month        Day
# 0            14.95  2019  December     Sunday
# 1            11.99  2019  December     Monday
# ...

# %%
df["Order Hour"] = df["Order Date"].dt.hour

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   294049  Lightning Charging Cable               1.0       14.95
# 1   294050          Wired Headphones               1.0       11.99
# 2   294051      USB-C Charging Cable               2.0       11.95
# 3   294052          Wired Headphones               1.0       11.99
# 4   294053          27in FHD Monitor               1.0      149.99
#
#            Order Date                         Purchase Address  \
# 0 2019-12-22 19:16:00      939 Odomankuma St, Kumasi, AS 40001
# 1 2019-12-30 18:15:00  116 Kwaku Boateng St, Sunyani, BA 10001
# 2 2019-12-25 16:17:00             924 1st St, Kumasi, AS 40001
# 3 2019-12-24 13:15:00                148 12th St, Wa, UE 48101
# 4 2019-12-06 21:21:00           172 Nii Armah St, Ho, VR 90001
#
#    Purchase Amount  Year     Month        Day  Order Hour
# 0            14.95  2019  December     Sunday          19
# 1            11.99  2019  December     Monday          18
# ...

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_region(address):
    return address.split(",")[2].split(" ")[1]

# %%
df["City"] = df["Purchase Address"].apply(lambda x: f" {get_city(x)}, ({get_region(x)}) ")

# %%
df.head(5)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   294049  Lightning Charging Cable               1.0       14.95
# 1   294050          Wired Headphones               1.0       11.99
# 2   294051      USB-C Charging Cable               2.0       11.95
# 3   294052          Wired Headphones               1.0       11.99
# 4   294053          27in FHD Monitor               1.0      149.99
#
#            Order Date                         Purchase Address  \
# 0 2019-12-22 19:16:00      939 Odomankuma St, Kumasi, AS 40001
# 1 2019-12-30 18:15:00  116 Kwaku Boateng St, Sunyani, BA 10001
# 2 2019-12-25 16:17:00             924 1st St, Kumasi, AS 40001
# 3 2019-12-24 13:15:00                148 12th St, Wa, UE 48101
# 4 2019-12-06 21:21:00           172 Nii Armah St, Ho, VR 90001
#
#    Purchase Amount  Year     Month        Day  Order Hour             City
# 0            14.95  2019  December     Sunday          19    Kumasi, (AS)
# ...
